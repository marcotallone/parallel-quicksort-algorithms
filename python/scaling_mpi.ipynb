# %% [markdown]
# # MPI Quicksort Analysis

# %%
from utils_mpi.preproc import *
from utils_mpi.plot import *

# Strong scaling data
dfs = preproc('../datasets/mpi_scaling_1e8.csv')

# Weak scaling data
dfw = preproc('../datasets/mpi_scaling_weak.csv')

# %%
# Plots

# Strong scaling plots
timeplot(dfs)
speedplot(dfs)

# Weak scaling plots
weaktimeplot(dfw)
effplot(dfw)
