# %% [markdown]
# # OpenMP Quicksort Analysis

# %%
from utils_omp.preproc import *
from utils_omp.plot import *

# Strong scaling data
dfs = preproc('../datasets/omp_scaling_1e7.csv')

# Weak scaling data
dfw = preproc('../datasets/omp_scaling_weak.csv')
# Out:
#      Method Sorted  Threads  Elements  Elements (Scientific)  \
# 0      task    Yes        2  10000000             10000000.0
# 1      task    Yes        4  10000000             10000000.0
# 2      task    Yes        6  10000000             10000000.0
# 3      task    Yes        8  10000000             10000000.0
# 4      task    Yes       10  10000000             10000000.0
# ..      ...    ...      ...       ...                    ...
# 108    psrs    Yes       58  10000000             10000000.0
# 109    psrs    Yes       60  10000000             10000000.0
# 110    psrs    Yes       62  10000000             10000000.0
# 111    psrs    Yes       64  10000000             10000000.0
# 112  serial    Yes        1  10000000             10000000.0
#
#      Average time (s)  St. Deviation (s)    Min (s)    Max (s)
# 0            6.462823           0.058365   6.373433   6.522995
# 1            3.685689           0.072393   3.621043   3.806330
# ...

# %%
# Strong scaling data
timeplot(dfs)
speedplot(dfs)

# Weak scaling plots
weaktimeplot(dfw)
effplot(dfw)
